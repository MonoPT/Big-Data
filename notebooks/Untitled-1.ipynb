# %%
# %pip install spark-nlp
# Out:
# Collecting spark-nlp
#   Downloading spark_nlp-6.2.2-py2.py3-none-any.whl.metadata (19 kB)
# Downloading spark_nlp-6.2.2-py2.py3-none-any.whl (744 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 744.4/744.4 kB 17.1 MB/s eta 0:00:0000:01
# Installing collected packages: spark-nlp
# Successfully installed spark-nlp-6.2.2

# %%
# !rm -r /content/sample_data
# !rm /content/.config
# Out:
# rm: cannot remove '/content/sample_data': No such file or directory
# rm: cannot remove '/content/.config': Is a directory

# %%
# !ls

# %%
# !git clone https://github.com/MonoPT/Big-Data.git /content/temp
# !mv /content/temp/* /content/
# Out:
# Cloning into '/content/temp'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 55 (delta 11), reused 48 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (55/55), 15.63 KiB | 7.81 MiB/s, done.
# Resolving deltas: 100% (11/11), done.
# Filtering content: 100% (12/12), 841.52 MiB | 50.81 MiB/s, done.

# %%
import os
import sparknlp
os.chdir("/content/notebooks")

# %%
from src import load_data

# %%
data = load_data.LoadData("/content/data")
spark = data.spark
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3262712612.py in <cell line: 0>()
# ----> 1 data = load_data.LoadData("/content/data")
#       2 spark = data.spark
#
# /content/notebooks/src/load_data.py in __init__(self, path)
#       3 class LoadData:
#       4     def __init__(self, path: str):
# ----> 5         self.spark = SparkSession.getActiveSession()
#       6
#       7         if spark is None:
#
# NameError: name 'SparkSession' is not defined

# %%
print(type(data.reviews))

# %%
applications.show(20)

# %%
data.spark
# Out:
# Hello
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://b31108dce662:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark NLP</code></dd>
#             </dl>
#         </div>
#
#             </div>
