# %%
# %pip install spark-nlp
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 744.4/744.4 kB 10.8 MB/s eta 0:00:00 0:00:01
# ...

# %%
# !git clone https://github.com/MonoPT/Big-Data.git /content/temp
# !mv /content/temp/* /content/
# !rm -r /content/temp/
# Out:
# Cloning into '/content/temp'...
# remote: Enumerating objects: 79, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 79 (delta 23), reused 68 (delta 12), pack-reused 0 (from 0)
# Receiving objects: 100% (79/79), 19.52 KiB | 3.90 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# Filtering content: 100% (12/12), 841.52 MiB | 27.17 MiB/s, done.

# %%
import os
import sparknlp
os.chdir("/content/notebooks")

# %%
from src import load_data

# %%
data = load_data.LoadData("/content/data")
spark = data.spark

# %%
print(type(data.reviews))
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>

# %%
data.applications.show(20)
# Out:
# +-----+--------------------+----+-------+------------+------------+--------------------+--------------------+--------------------+--------------------+----------------+---------------------+--------------------+----------------+------------------+-----------------+---------------+--------------------+------------+---------------------+--------------------+--------------------+-----------------+--------------------+-------------+--------------------+-----------------+-------------------+--------------------+--------------------+
# ...
