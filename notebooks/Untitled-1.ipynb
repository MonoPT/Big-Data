# %%
# %pip install spark-nlp

# %%
import sparknlp

# %%
#spark = sparknlp.start()

# %%
# !git clone https://github.com/MonoPT/Big-Data.git
# !mv /content/Big-Data/data /content/data
# !mv /content/Big-Data/notebooks/src /content/src
# !rm -r Big-Data
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# fatal: could not create work tree dir 'Big-Data': No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# mv: cannot stat '/content/Big-Data/data': No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# mv: cannot stat '/content/Big-Data/notebooks/src': No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# rm: cannot remove 'Big-Data': No such file or directory

# %%
# !ls
# Out:
# data  sample_data  src

# %%
application_categories = spark.read.csv('/content/data/application_categories.csv', header=True, inferSchema=True, multiLine=True, escape='"')
application_developers = spark.read.csv('/content/data/application_developers.csv', header=True, inferSchema=True, multiLine=True, escape='"')
application_genres = spark.read.csv('/content/data/application_genres.csv', header=True, inferSchema=True, multiLine=True, escape='"')
application_platforms = spark.read.csv('/content/data/application_platforms.csv', header=True, inferSchema=True, multiLine=True, escape='"')
application_publishers = spark.read.csv('/content/data/application_publishers.csv', header=True, inferSchema=True, multiLine=True, escape='"')
applications = spark.read.csv('/content/data/applications.csv', header=True, inferSchema=True, multiLine=True, escape='"')
categories = spark.read.csv('/content/data/categories.csv', header=True, inferSchema=True, multiLine=True, escape='"')
developers = spark.read.csv('/content/data/developers.csv', header=True, inferSchema=True, multiLine=True, escape='"')
genres = spark.read.csv('/content/data/genres.csv', header=True, inferSchema=True, multiLine=True, escape='"')
platforms = spark.read.csv('/content/data/platforms.csv', header=True, inferSchema=True, multiLine=True, escape='"')
publishers = spark.read.csv('/content/data/publishers.csv', header=True, inferSchema=True, multiLine=True, escape='"')
reviews = spark.read.csv('/content/data/reviews.csv', header=True, inferSchema=True, multiLine=True, escape='"')

# %%
print(type(reviews))
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>

# %%
applications.show(20)
# Out:
# +-----+--------------------+----+-------+------------+------------+--------------------+--------------------+--------------------+--------------------+----------------+---------------------+--------------------+----------------+------------------+-----------------+---------------+--------------------+------------+---------------------+--------------------+--------------------+-----------------+--------------------+-------------+--------------------+-----------------+-------------------+--------------------+--------------------+
# ...

# %%
from src import load_data

load_data.LoadData("/content/data")
# Out:
# Hello
