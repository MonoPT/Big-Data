# %%
# %pip install spark-nlp
# Out:
# Requirement already satisfied: spark-nlp in /usr/local/lib/python3.12/dist-packages (6.2.2)

# %%
# !rm -r /content/sample_data
# !rm /content/.config
# Out:
# rm: cannot remove '/content/sample_data': No such file or directory
# rm: cannot remove '/content/.config': Is a directory

# %%
# !git clone https://github.com/MonoPT/Big-Data.git /content/temp
# !mv /content/temp/* /content/
# Out:
# Cloning into '/content/temp'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 67 (delta 17), reused 58 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (67/67), 17.76 KiB | 2.22 MiB/s, done.
# Resolving deltas: 100% (17/17), done.
# Filtering content: 100% (12/12), 841.52 MiB | 35.54 MiB/s, done.

# %%
import os
import sparknlp
os.chdir("/content/notebooks")

# %%
from src import load_data

# %%
from pyspark.sql import SparkSession
# Out:
# None

# %%
data = load_data.LoadData("/content/data")
spark = data.spark
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-455902889.py in <cell line: 0>()
# ----> 1 data = load_data.LoadData("/content/data")
#       2 print(data)
#
# /content/notebooks/src/load_data.py in __init__(self, path)
#      10             self.spark = sparknlp.start()
#      11
# ---> 12         self.application_categories = spark.read.csv(f'/content/data/application_categories.csv', header=True, inferSchema=True, multiLine=True, escape='"')
#      13         self.application_developers = spark.read.csv('/content/data/application_developers.csv', header=True, inferSchema=True, multiLine=True, escape='"')
#      14         self.application_genres = spark.read.csv('/content/data/application_genres.csv', header=True, inferSchema=True, multiLine=True, escape='"')
#
# NameError: name 'spark' is not defined

# %%
print(type(data.reviews))

# %%
applications.show(20)

# %%
data.spark
# Out:
# Hello
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://b31108dce662:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark NLP</code></dd>
#             </dl>
#         </div>
#
#             </div>
